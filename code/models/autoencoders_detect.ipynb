# %%
# detect anomaly using autoencoders
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score

# %%
# load data
df = pd.read_csv('data/m16_cpu_usage_clean.csv')

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df.head()
# Out:
#                        time  cpu_util
# 0 2017-11-05 02:00:00+00:00  0.279063
# 1 2017-11-05 02:05:00+00:00  0.274687
# 2 2017-11-05 02:10:00+00:00  0.293007
# 3 2017-11-05 02:15:00+00:00  0.290867
# 4 2017-11-05 02:20:00+00:00  0.288103

# %%
# plot data
plt.figure(figsize=(20, 5))
plt.plot(df['time'], df['cpu_util'])
plt.title('CPU Usage')
plt.xlabel('Time')
plt.ylabel('CPU Usage')
plt.show()

# %%
# split data
train, test = train_test_split(df, test_size=0.2, random_state=0)
train.shape, test.shape
# Out:
# ((9376, 2), (2345, 2))

# %%
# scale data
scaler = StandardScaler()
scaler = scaler.fit(train[['cpu_util']])
train['cpu_util'] = scaler.transform(train[['cpu_util']])
test['cpu_util'] = scaler.transform(test[['cpu_util']])
train.head()
# Out:
#                            time  cpu_util
# 2405  2017-11-13 10:25:00+00:00  0.180239
# 9413  2017-12-07 18:25:00+00:00 -0.064241
# 10590 2017-12-11 20:30:00+00:00 -1.095140
# 2701  2017-11-14 11:05:00+00:00  0.475516
# 4237  2017-11-19 19:05:00+00:00 -1.263697
